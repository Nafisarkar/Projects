# %%
import pandas as pd

# %%
df = pd.read_csv("D:\Projects\Test\Data\student-dataset.csv")
df
# Out:
#     id               name               nationality                 city  \
# 0    0          Kiana Lor                     China               Suzhou
# 1    1     Joshua Lonaker  United States of America        Santa Clarita
# 2    2      Dakota Blanco  United States of America              Oakland
# 3    3    Natasha Yarusso  United States of America        Castro Valley
# 4    4     Brooke Cazares                    Brazil  São José dos Campos
# ..  ..                ...                       ...                  ...
# 57  57       Amanda Tatum  United States of America            San Diego
# 58  58  Cameron Steinberg  United States of America          Los Angeles
# 59  59   Shuraih el-Karim                  Pakistan             Khalabat
# 60  60      Katelyn Sharp  United States of America          Los Angeles
# 61  61       Colin Lemont                     China             Shanghai
#
#     latitude  longitude gender  ethnic.group   age  english.grade  math.grade  \
# ...

# %%
df.isna()
# Out:
#        id   name  nationality   city  latitude  longitude  gender  \
# 0   False  False        False  False     False      False   False
# 1   False  False        False  False     False      False   False
# 2   False  False        False  False     False      False   False
# 3   False  False        False  False     False      False   False
# 4   False  False        False  False     False      False   False
# ..    ...    ...          ...    ...       ...        ...     ...
# 57  False  False        False  False     False      False   False
# 58  False  False        False  False     False      False   False
# 59  False  False        False  False     False      False   False
# 60  False  False        False  False     False      False   False
# 61  False  False        False  False     False      False   False
#
#     ethnic.group    age  english.grade  math.grade  sciences.grade  \
# 0           True  False          False       False           False
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# name                   0
# nationality            0
# city                   0
# latitude               0
# longitude              0
# gender                 0
# ethnic.group          62
# age                    7
# english.grade          9
# math.grade            10
# sciences.grade         5
# language.grade         8
# portfolio.rating       5
# coverletter.rating     3
# refletter.rating       4
# dtype: int64

# %%
avgAge = int(df["age"].mean())
avgEng =  int(df["english.grade"].mean())
avgMath =  int(df["math.grade"].mean())


print("Average age: ", avgAge)

df['age'].fillna(avgAge, inplace=True)
df['english.grade'].fillna(avgEng, inplace=True)
df['math.grade'].fillna(avgMath, inplace=True)
# Out:
# Average age:  22

# %%
df.fillna(method= "pad")
# Out:
#     id               name               nationality                 city  \
# 0    0          Kiana Lor                     China               Suzhou
# 1    1     Joshua Lonaker  United States of America        Santa Clarita
# 2    2      Dakota Blanco  United States of America              Oakland
# 3    3    Natasha Yarusso  United States of America        Castro Valley
# 4    4     Brooke Cazares                    Brazil  São José dos Campos
# ..  ..                ...                       ...                  ...
# 57  57       Amanda Tatum  United States of America            San Diego
# 58  58  Cameron Steinberg  United States of America          Los Angeles
# 59  59   Shuraih el-Karim                  Pakistan             Khalabat
# 60  60      Katelyn Sharp  United States of America          Los Angeles
# 61  61       Colin Lemont                     China             Shanghai
#
#     latitude  longitude gender  ethnic.group   age  english.grade  math.grade  \
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# name                   0
# nationality            0
# city                   0
# latitude               0
# longitude              0
# gender                 0
# ethnic.group          62
# age                    0
# english.grade          0
# math.grade             0
# sciences.grade         5
# language.grade         8
# portfolio.rating       5
# coverletter.rating     3
# refletter.rating       4
# dtype: int64

# %%
df.drop("ethnic.group", axis=1, inplace=True)
df
# Out:
#     id               name               nationality                 city  \
# 0    0          Kiana Lor                     China               Suzhou
# 2    2      Dakota Blanco  United States of America              Oakland
# 3    3    Natasha Yarusso  United States of America        Castro Valley
# 4    4     Brooke Cazares                    Brazil  São José dos Campos
# 5    5   Rochelle Johnson  United States of America         Indianapolis
# ..  ..                ...                       ...                  ...
# 57  57       Amanda Tatum  United States of America            San Diego
# 58  58  Cameron Steinberg  United States of America          Los Angeles
# 59  59   Shuraih el-Karim                  Pakistan             Khalabat
# 60  60      Katelyn Sharp  United States of America          Los Angeles
# 61  61       Colin Lemont                     China             Shanghai
#
#     latitude  longitude gender   age  english.grade  math.grade  \
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#     id                name               nationality           city  latitude  \
# 0    0           Kiana Lor                     China         Suzhou     31.31
# 2    2       Dakota Blanco  United States of America        Oakland     37.80
# 3    3     Natasha Yarusso  United States of America  Castro Valley     37.69
# 5    5    Rochelle Johnson  United States of America   Indianapolis     39.77
# 6    6          Joey Abreu                     China       Shenyang     41.79
# 8    8            Lee Dong               Philippines         Manila     14.60
# 9    9       Maa'iz al-Dia                    Turkey       Istanbul     41.02
# 10  10      Maja Nicholson  United States of America         Dallas     32.78
# 11  11        Sasha Jansen  United States of America        Chicago     41.85
# 12  12   Alexander Sherman  United States of America          Omaha     41.26
# 14  14        Kolbi Strunk  United States of America  Mission Viejo     33.60
# ...

# %%
df.to_csv('testtatagsdgasgasdg.csv', index=False)
